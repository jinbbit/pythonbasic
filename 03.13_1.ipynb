# %% [markdown]
# # Matplotlib (1)
#  : 파이썬에서 Chart나 Plot으로 시각화 하는 패키지

# %% [markdown]
# Matplotlib이란
# Matplotlib은 파이썬에서 자료를 차트(chart)나 플롯(plot, a graph showing the relation of two variables)으로 시각화하는 패키지입니다.
#
# Matplotlib은 다음과 같은 정형화된 차트나 플롯 등 다양한 시각화 기능을 제공합니다.
#
# - 라인 플롯(line plot)
# - 스캐터 플롯(scatter plot)
# - 컨투어 플롯(contour plot)
# - 서피스 플롯(surface plot)
# - 바 차트(bar chart)
# - 히스토그램(histogram)
# - 박스 플롯(box plot)

# %% [markdown]
# ### < matplotlib 및 matplotlib.pyplot 임포트하기 >
#
# matplotlib 패키지에는 pyplot 라는 서브패키지가 존재합니다.
#
# 이 pyplot 서브패키지는 매트랩(matlab) 이라는 수치해석 소프트웨어의 시각화 명령을 제공합니다.
#
# 간단한 시각화 프로그램을 만드는 경우에는 pyplot 서브패키지의 명령만으로도 충분합니다.
#
# matplotlib 패키지를 사용할 때는 보통 다음과 같이 주 패키지는 mpl 이라는 별칭(alias)
# 으로 임포트하고 pyplot 서브패키지는 plt 라는 다른 별칭으로 임포트하여 사용하는 것이
# 관례입니다.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# #### 만약 그래프가 출력되지 않는다면
#
# Jupyter 개발 환경이 아닌 non-interactive python의 경우, matplotlib을 활용하여 그래프를 그리면 그 결과로 별도의 Window를 띄웁니다.
#
# 반대로 Jupyter(interactive python, ipython)에서는 웹페이지로 표현되기 때문에 별도의 윈도우를 띄워서 Figure를 표현할 수 없습니다.
#
# 이런 Jupyter의 특징 때문에, 경우에 따라서 시각화 결과물인 그래프가 출력되지 않는 경우가 발생됩니다.
#
# 그때는 다음처럼 %matplotlib 매직(magic) 명령으로 주피터 내부에 그림을 표시하도록 지정해야 합니다.

# %%
# %matplotlib inline

# %% [markdown]
# ![image.png](attachment:a718f8f0-d984-4d46-b77f-45d07f7783dd.png)

# %% [markdown]
# ### < 라인 플롯(line plot) - x 축의 위치(tick) >
#
# x 축의 위치를 x 틱(tick)이라고 합니다. default는 0, 1, …, N-1 범위의 index array입니다.
#
# x tick을 지정하려면 두 개의 같은 길이의 리스트 혹은 배열 자료를 넣으면 됩니다.
#
# ![image.png](attachment:0b6eadeb-0114-4c7a-b9d0-8f454d6b9023.png)

# %%
plt.title("Plot")
plt.plot([1, 4, 9, 16])      # x는 생략하게 되며는 0부터 차례대로
plt.show()

# %%
plt.title("x ticks")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.show()

# %% [markdown]
# ### < 라인 플롯(line plot) - title() >
# title()는 플롯의 제목을 의미합니다.
# ![image.png](attachment:5d8f07ef-98e4-4b54-949f-5e1cae75c6da.png)

# %% [markdown]
# ### < 라인 플롯(line plot) >
#
# show()는 플롯을 그림으로 표시합니다.
#
# 주피터 랩과 같이 ipython(Interactive Pyhotn) 환경에서 실행할 경우 모든 수치를 표시하고 ipython 프롬프트로 돌아갑니다.

# %% [markdown]
# ![image.png](attachment:ba004292-12e4-4089-b807-cdcb0c4a85c0.png)

# %% [markdown]
# 직접 아나콘다prompt에서 실행
# ![image.png](attachment:8b086eb3-1c75-43ed-977e-19dab65df022.png)
# 그래프 내 좌표값도 찍어볼 수 있고, 확대-축소도 가능함

# %% [markdown]
# ### < 한글 폰트 사용하기 >
# 한글 제목을 사용하기 위해 title()의 인수로 한글 문자열을 전달하면 아래처럼 제대로
# 표현되지 않음을 확인할 수 있습니다.

# %%
plt.title("한글 제목")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44544 (\N{HANGUL SYLLABLE GEUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47785 (\N{HANGUL SYLLABLE MOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [raw]
# 현재 폰트가 없어서 저렇게 뜸

# %% [markdown]
# ### < 한글 폰트 사용하기 - 시스템 폰트 사용하기 >
# Path 중간에 한글 경로가 포함되는지 꼭 확인합니다.
#
# 만약 있다면 이를 지양합니다.

# %%
# 시스템 폰트 경로 리스트
font_list = mpl.font_manager.findSystemFonts()
print(font_list)
# Out:
# ['C:\\Windows\\Fonts\\timesi.ttf', 'C:\\Windows\\Fonts\\GOTHICI.TTF', 'C:\\Windows\\Fonts\\verdanaz.ttf', 'C:\\Windows\\Fonts\\georgia.ttf', 'C:\\Windows\\Fonts\\GILSANUB.TTF', 'C:\\Windows\\Fonts\\arialbi.ttf', 'C:\\Windows\\Fonts\\LTYPE.TTF', 'C:\\Windows\\Fonts\\INFROMAN.TTF', 'C:\\Windows\\Fonts\\BRLNSDB.TTF', 'C:\\Windows\\Fonts\\H2MJRE.TTF', 'C:\\Windows\\Fonts\\GILC____.TTF', 'C:\\Windows\\Fonts\\wingding.ttf', 'C:\\Windows\\Fonts\\malgunbd.ttf', 'C:\\Windows\\Fonts\\BOOKOSB.TTF', 'C:\\Windows\\Fonts\\\x7f\x7f\x7f\x7fBOLD.TTF', 'C:\\Windows\\Fonts\\YuGothR.ttc', 'C:\\Windows\\Fonts\\VLADIMIR.TTF', 'C:\\Windows\\Fonts\\GOUDOSI.TTF', 'C:\\Windows\\Fonts\\constani.ttf', 'C:\\Windows\\Fonts\\ARIALN.TTF', 'C:\\Windows\\Fonts\\segoeuisl.ttf', 'C:\\Windows\\Fonts\\GILI____.TTF', 'C:\\Windows\\Fonts\\BOD_CBI.TTF', 'C:\\Windows\\Fonts\\FRAMDCN.TTF', 'C:\\Windows\\Fonts\\GOTHIC.TTF', 'C:\\Windows\\Fonts\\H2GTRM.TTF', 'C:\\Windows\\Fonts\\ANTQUAB.TTF', 'C:\\Windows\\Fonts\\msyhbd.ttc', '
# ...

# %% [raw]
# 폰트 파일에 대한 경로들. 외울필요 없고 필요할 때 위에서 원하는 폰트 경로 복붙해

# %% [raw]
# # 폰트 설정하기
# prop = mpl.font_manager.FontProperties(fname='원하는 폰트 경로')
# plt.rcParams['font.family'] = prop.get_family()
#
# 저기 원하는 폰트 경로에 찾아서 복붙해서 넣어야함

# %% [markdown]
# ### < 한글 폰트 사용하기 - Font 설치하기 >

# %% [markdown]
# 외부폰트

# %%
# %pwd
# Out:
# 'C:\\python'

# %%
import matplotlib as mpl
# Add every font at the specified location
font_dir = ['c:\\python\\fonts']
for font in mpl.font_manager.findSystemFonts(fontpaths=font_dir):
    print(mpl.font_manager.FontProperties(fname=font).get_name())  # 가져온 경로값을 가지고 이름을 지정
    mpl.font_manager.fontManager.addfont(font) # 외부폰트 추가
# Out:
# NanumGothic Eco
# NanumBarunpenOTF
# NanumSquare Neo ExtraBold
# NanumSquare Neo OTF ExtraBold
# NanumGothicOTF
# NanumSquareRound
# NanumMyeongjoOTF Eco
# NanumSquareOTF
# NanumSquare_ac
# Noto Serif KR
# NanumSquare Neo OTF Bold
# Noto Serif KR
# NanumBarunGothicOTF YetHangul
# NanumSquareOTF
# NanumMyeongjoOTF
# NanumSquareOTF_ac
# Nanum Pen Script OTF
# NanumSquareRound
# NanumMyeongjo Eco
# NanumBarunGothicOTF
# NanumMyeongjo Eco
# NanumSquareRound
# NanumSquare_ac
# NanumSquare Neo OTF Regular
# Noto Sans KR
# NanumGothicOTF Eco
# NanumSquare
# NanumGothic
# NanumMyeongjo YetHangul
# NanumSquareRound
# NanumSquareRoundOTF
# D2Coding
# Noto Sans KR
# NanumMyeongjoOTF Eco
# NanumGothic
# NanumSquare
# NanumMyeongjoOTF Eco
# NanumBarunGothic
# NanumGothic
# NanumMyeongjo
# NanumSquare_ac
# Noto Sans KR
# NanumSquare Neo Heavy
# NanumSquare
# D2Coding ligature
# Noto Serif KR
# NanumBarunGothic
# NanumSquare Neo OTF Heavy
# NanumSquare Neo OTF Light
# NanumBarunGothic YetHangul
# ...

# %%
# Set font family globally
mpl.rcParams['font.family'] = 'Noto Sans KR'
print(mpl.rcParams['font.family'])
# Out:
# ['Noto Sans KR']

# %%
plt.title("한글")
plt.plot(range(1, 5))
plt.show()

# %% [markdown]
# ### < 한글 폰트 사용하기 - Font scope >
#
# 설치된 폰트를 사용하는 방법은 크게 두 가지 입니다.
#
# 1. mpl.rc(‘font’, family=’폰트명’) 메서드를 통한 설정으로 전체 범위에 대해 적용하기 위 코드는 mpl.rcParams[“font.family”] = ‘폰트명' 과 같습니다.
#
# 2. fontdict keyword argument를 사용하여 세부적으로 적용하는 방법

# %% [markdown]
# ### < 한글 폰트 사용하기 - matplotlib.pyplot.rc() >
#
# 한글 문자열은 항상 유니코드(e.g. UTF-8)를 사용해야 합니다.
# 우선 우리가 학습하는 동안 전체 범위에서 한글을 사용하기 위해서 mlp.rc()를 통하여 전체 영역에 대한 폰트
# 설정을 변경해줍니다.
# mlp.rc(‘rcParams’, 변경할 값을 키워드 인수로 전달)는 rcParams를 변경해주는
# 메서드입니다.

# %% [markdown]
# ![image.png](attachment:11b09b32-8132-4864-abc3-26c7fb973aea.png)

# %%
global_font = {'family' : 'NanumGothic', 'size' : 12, 'weight' : 'bold'}

# 폰트 설정
mpl.rc('font', **global_font) # pass in the font dict as kwrgs
# mpl.rc('family' : 'NanumGothic', 'size' : 12, 'weight' : 'bold') 와 같이 동작함.

# %% [markdown]
# ### RcParams로 설정할 수 있는 font 설정들
# https://matplotlib.org/stable/api/matplotlib_configuration_api.html#matplotlib.RcParams

# %% [markdown]
# ![image.png](attachment:aa5ef486-56bc-4652-8b07-405d46794f85.png)

# %% [markdown]
# ### <한글 폰트 사용하기 - 기본 폰트 확인 >
#
# 앞의 과정을 잘 따라와서 정상적으로 폰트를 설치하고 rcParams인 font를 제대로
# 설정했다면 아래 예제 코드를 실행하였을 때 한글 문자열이 잘 출력돼야 합니다.

# %%
plt.title('한글 제목')
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.xlabel('엑스측 레이블')
plt.ylabel('와이측 레이블')
plt.show()

# %% [markdown]
# ### < 한글 폰트 사용하기 - 개별 폰트 설정하기 >
#
# 만약 객체마다 별도의 폰트를 적용하고 싶을 때는 다음과 같이 폰트 family, color, size를 dict 타입으로 정의하고, 이 dict
# 변수를 플롯 메서드의 fontdict 키워드 인수로 전달하면 됩니다.
#
# 그럼 각각 폰트가 적용된 것을 확인할 수 있습니다.

# %%
title_font = {'family' : 'NanumMyeongjo',
              'size' : 24,
              'color' : 'black' }
xlabel_font = {'family' : 'NanumBarunpen',
               'size' : 18,
               'color' : 'yellow' }
ylabel_font = {'family' : 'NanumBarunGothic',
               'size' : 12,
               'weight' : 'light',
               'color' : 'blue' }

plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.title('한글 제목', fontdict = title_font)
plt.xlabel('엑스측 레이블', fontdict = xlabel_font)
plt.ylabel('와이측 레이블', fontdict = ylabel_font)
plt.show()

# %% [markdown]
# https://matplotlib.org/stable/gallery/text_labels_and_annotations/unicode_minus.html

# %% [markdown]
# ### < Unicode minus 표기법 설정 >
#
# 음수 부호를 유니코드와 ASCII 중 어떤 문자로 표기할지 설정합니다.
#
# rc() 메서드로 RcParams 중 axes.unicode_minus의 값을 False로 변경하면 ASCII의 문자로 표현됩니다.

# %%
# 유니코드에서 음수 부호설정
mpl.rc('axes', unicode_minus = False)

# %% [markdown]
# 유니코드 방식이 마이너스가 이따금씩 깨져서 아스키 문자로 표현
# ![image.png](attachment:83e78ad5-20f7-495f-9bf1-0367537659b2.png)

# %% [markdown]
# ### < Style 설정하기 >
#
# 플롯 명령어는 보는 사람이 그림을 더 알아보기 쉽게 하기 위해 다양한 스타일(style)을
# 지원합니다.
#
# plot 명령어에서는 다음과 같이 추가 문자열 인수를 사용하여 스타일을
# 지원합니다

# %%
plt.title("default 스타일의 plot ")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.show()

# %%
# 선의 모양, 색상, 마커 스타일
plt.title("'rs--' 스타일의 plot")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], 'rp--')
plt.show()

# %% [markdown]
# ### < Style 설정하기 - style 설정하는 순서 >
#
# 스타일 문자열은 색상(color), 마커(marker), 선 종류(line style)의 순서로 지정한다.
#
# 만약 이 중 일부가 생략되면 디폴트값이 적용됩니다.
# ![image.png](attachment:a9152d75-d034-4254-b058-ebd4b86a9b21.png)

# %% [markdown]
# ### < Style 설정하기 - color >
#
# 색깔을 지정하는 방법은 색 이름 혹은 약자를 사용하거나 # 문자로 시작되는 RGB코드를 사용합니다.
#
# https://matplotlib.org/2.0.2/examples/color/named_colors.html
# * 색상표 들어가서 사용해
# ![image.png](attachment:0a265255-8e2b-4c19-8521-9c133d7f6422.png)

# %% [markdown]
# ### < Style 설정하기 - marker >
#
# 데이터 위치를 나타내는 기호를 마커(marker)라고 한다. 마커의 종류는 다음과 같습니다.
#
# https://matplotlib.org/2.0.2/api/markers_api.html?highlight=marker#module-matplotlib.markers
#
# ![image.png](attachment:d85ff552-4114-4f01-bdd6-128e962c0fb8.png)

# %% [markdown]
# ### < Style 설정하기 - linestyle >
#
# 선 스타일의 지정 문자열은 다음과 같다.
#
# https://matplotlib.org/2.0.2/api/lines_api.html?highlight=line%20style#matplotlib.lines.Line2D.set_linestyle
#
# ![image.png](attachment:776c2551-951d-40ad-8c6c-e55aada0aa30.png)

# %% [markdown]
# ### < Style 설정하기 - 기타 style >
#
# 라인 플롯에서는 앞서 설명한 세 가지 스타일 color, marker, linestyle 외에 여러가지 스타일을 지정할 수 있습니다.
#
# ![image.png](attachment:5f86266a-5720-4095-8a37-3e27202c4413.png)
#
# 외우지 말고 그때그때 필요한거 표를 찾아서 쓰자

# %% [markdown]
# ### < Style 설정하기 - 기타 style >
#
# 아래 코드에서는 선 색상(c)을 b(blue), 선 굵기(lw)를 5, marker를 circle(o), marker
# size(ms)를 15, 마커 선 색상(mec)을 g(green)으로, 마커 선 굵기(mew)를 5, 마커 내부
# 색상을 r(red)로 지정하였습니다.

# %%
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], c = "b",
         lw = 5, ls = "--", marker = "o", ms = 15, mec = "g", mew = 5, mfc = "r")
plt.title("스타일 적용 예")
plt.show()

# %% [markdown]
# ### < 축의 범위 설정하기 >
#
# 플롯 그림을 보면 몇몇 점들은 그림의 범위 경계선에 있어서 잘 보이지 않는 경우가 있을 수 있습니다.
#
# 그림의 범위를 수동으로 지정하려면 xlim(최소값, 최대값)과 ylim(최소값, 최대값)을 사용합니다.
#
# 이는 x축, y축의 최소값과 최대값을 지정합니다.

# %%
plt.title("x축, y축의 범위 설정")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], 
         c = "b", lw = 5, ls = "--", marker = "o", ms = 15, mec = "g", mew = 5, mfc = "r")
plt.xlim(0, 50)
plt.ylim(-10, 30)
plt.show()

# %% [markdown]
# ### < 틱 설정하기 >
#
# 플롯이나 차트에서 축상의 위치 표시 지점을 틱(tick)이라고 하고 이 틱에 써진 숫자 혹은 글자를 틱 라벨(tick label)이라고 합니다.
#
# 틱의 위치나 틱 라벨은 맷플롯리브가 자동으로 정해주지만 만약 수동으로 설정하고 싶다면 xticks()이나 yticks()을 사용합니다.

# %%
import numpy as np
X = np.linspace(-np.pi, np.pi, 256)  # 등간격으로 자른 것
C = np.cos(X) # 등간격으로 코사인그래프로

plt.title("x축, y축의 tick label 설정")
plt.plot(X, C)
plt.xticks([-np.pi, np.pi / 2, 0, np.pi / 2, np.pi]) 
plt.yticks([-1, 0, +1])
plt.show()

# %% [markdown]
# ### < 틱 설정하기 >
#
# 틱 라벨 문자열에는 $$ 사이에 수학 문자식(Mathematical expressions)을 넣을 수도 있습니다.
#
# 다양한 mathematical expressions은 아래 링크를 통해 확인할 수 있습니다.

# %%
X = np.linspace(-np.pi, np.pi, 256)
C = np.cos(X)

plt.title("Tex, 문자열로 tick label 설정")
plt.plot(X, C)
plt.xticks([-np.pi, np.pi / 2, 0, np.pi / 2, np.pi],
           [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1, 0, +1], ["Low", "Zero", "High"])
plt.show()

# %% [raw]
#  [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$']
#  밑에 x축을 파이로 표현

# %% [markdown]
# ### < 여러 개의 선 그리기 >
#
# 라인 플롯에서 선을 하나가 아니라 여러개를 그리고 싶은 경우에는 x 데이터, y 데이터, 스타일 문자열을 반복하여 인수로 넘깁니다.
#
# 이 경우에는 하나의 선을 그릴 때 처럼 x 데이터나 스타일 문자열을 생략할 수 없습니다.

# %%
t = np.arange(0., 5., 0.2)
plt.title("라인 플롯에서 여러개의 선 그리기")
plt.plot(t, t, 'r--', t, 0.5 * t**2, 'bs:', t, 0.2 * t**3, 'g^-')
plt.show()

# %% [markdown]
# ### < 여러 개의 선 그리기 >
# 하나의 plot()이 아니라 복수의 plot()을 하나의 그림에 겹쳐서 그릴 수도 있다

# %%
plt.title("복수의 plot 명령을 한 그림에서 표현")
style1 = {"c":"b", 'lw' : 5, 'ls' : '--', 'marker' : 'o', 'ms' : 15, 'mec' : 'g', 'mew' : 5, 'mfc' : 'r'}
style2 = {"c":"k", 'lw' : 3, 'ls' : ':', 'marker' : 's', 'ms' : 10, 'mec' : 'm', 'mew' : 5, 'mfc' : 'c'}

plt.plot([1, 4, 9, 16], **style1)
plt.plot([9, 16, 4, 1], **style2)

plt.show()

# %% [markdown]
# ### < 범례(Legend) >
#
# 여러개의 라인 플롯을 동시에 그리는 경우에는 각 선이 무슨 자료를 표시하는지를 보여주기 위해 legend 명령으로 범례(legend)를 추가할 수 있습니다.
#
# 범례의 위치는 자동으로 정해지지만 수동으로 설정하고 싶으면 loc 키워드 인수를 사용합니다.
#
# ![image.png](attachment:e32df0e3-6a1a-4955-a9b7-534672dea686.png)

# %% [markdown]
# ### < 범례(Legend) >
#
# 아래 예제에서는 각 plot마다 label 키워드 인수를 통해 legend label을 설정하고 legend() 메서드에 loc 키워드 인자에 2를 전달함으로써 좌측 상단에 legend 위치하라고 명시하고
# 있습니다.

# %%
X = np.linspace(-np.pi, np.pi, 256)  
C, S = np.cos(X), np.sin(X)

plt.title("legend를 표시한 플롯")
plt.plot(X, C, ls = "--", label = "cosine")
plt.plot(X, S, ls = ":", label = "sine")
plt.legend(loc = 2)  # upper left
plt.show()

# %% [raw]
# 범례 위치 loc는 생략가능하나, 위치를 정확히 주고싶으면 앞에 표를 참고하여 원하는 위치에 범례 지정 가능

# %% [markdown]
# ### < x, y축 label >
#
# 플롯의 x축 위치와 y축 위치에는 각각 그 데이터가 의미하는 바를 표시하기 위해 라벨(label)를 추가할 수 있습니다.
# 라벨을 붙이려면 xlabel(), ylabel()을 사용합니다.

# %%
X = np.linspace(-np.pi, np.pi, 256)  
C, S = np.cos(X), np.sin(X)

plt.title("Cosine Plot")
plt.plot(X, C, label = "cosine")
plt.xlabel("time")
plt.ylabel("amplitude")
plt.show()

# %% [markdown]
# ### < 연습 문제 >
#
# 다음과 같은 그래프를 그려보세요.
#
# - title: 섭씨 온도와 화씨 온도
# - xlabel: 화씨 온도
# - ylabel: 섭씨 온도
# - x 값은 화씨로 32이상~100미만의 정수, y 값은 섭씨로 ℃ = (℉ − 32) × 5/9 를 통해 구합니다.

# %%
x = np.arange(32, 100)
y = (x - 32) * 5/9

plt.title("섭씨 온도와 화씨 온도")
plt.plot(x, y, 'r-.')
plt.xlabel("화씨 온도")
plt.ylabel("섭씨 온도")
plt.show()

# %% [markdown]
# ### < 내용 요약 >
#
# https://matplotlib.org/stable/tutorials/introductory/quick_start.html#parts-of-a-figure
#
# ![image.png](attachment:b61d8c22-b54f-429b-b768-3651335a96f7.png)
#
# tick / ylabel / y Axis / x Axis / xlabel /
#
# Line / Markers
#
# Fiture

# %% [markdown]
# ### < 내용 요약 >
#
# https://docs.wradlib.org/en/stable/notebooks/python/mplintro.html
#
# ![image.png](attachment:93b9c7b3-2a24-4afc-957b-b2a2ae0c76f3.png)

# %% [markdown]
# ### < Figure >
#
# Matplotlib는 data를 Figure(e.g. windows, Jupyter widgets, etc.)에 x-y 좌표의 그래프로 표시합니다(3차원은 x-y-z, 극좌표는 세타-r 등).
#
# 각각의 Figure는 하나 이상의 Axes를 갖습니다.
#
# 가장 간단하게 Figure, Axes 객체를 만드는 방법은 pyplot.subplots()을 사용하는 것입니다.
#
# 그 후 Axes.plot()를 활용하여 Axes에 데이터를 그립니다.

# %%
fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4], [1, 4, 2, 3]);

# %% [markdown]
# Figure는 전체 그림(그래프)을 의미하는 객체입니다. Figure 객체는 Axes, 특수 Artist 그룹(title, figure legends, colorbar, etc), 그리고 심지어 중첩된subfigures까지 포함할 수 있습니다.
#
# 가장 쉬운 방법으로 Figure 객체를 생성하는 방법들입니다. Axes 없이 Figure만 얻으려면 figure() 메서드를 사용하면 됩니다. 1개의 Axes 객체를 갖는 Figure를 만들기 위해선 subplots() 메서드를 인수 없이 사용하면 됩니다.
#
# ********** subplots 와 뒤에 나오는 supbplot 의 차이 분명히!!!!!!!!!!!**********
#
# grid 형태의 shape을 갖는 Axes 객체를 여럿 만들 땐 subplot() 메서드에 첫 인수로 row를 두 번째 인수로 column을 입력합니다.

# %%
fig = plt.figure() # an empty figure with no Axes
fig, ax = plt.subplots() # a figure with a single Axes
fig, axs = plt.subplots(2, 2) # a figure with a 2x2 grid of Axex

# %% [markdown]
# ### < Figure - plt.plot() >
#
# 원래 Figure 객체를 생성하려면 figure()을 사용하여 그 반환값으로 Figure 객체를 얻어야 합니다.
#
# 그러나 plot() 명령만 실행해도 자동으로 Figure 객체를 생성해주기 때문에 일반적으로는 figure()를 잘 사용하지 않습니다.
#
# figure()을 명시적으로 사용하는 경우는 여러 개의 Windows를 동시에 띄워야 하거나 (non-interactive python), Jupyter lab 등에서(ipython) 그림의 크기를 설정하고 싶을 때 사용합니다.
#
# 그림의 크기는 figsize 인수로 설정합니다.

# %%
np.random.seed(0)
f1 = plt.figure(figsize = (10, 2))
plt.title("figure size : (10, 2)")
plt.plot(np.random.randn(100))
plt.show()

# %% [markdown]
# ### < Figure - plt.show()가 그래프를 그리는 방식의 차이 >
#
# ipython의 형태인 주피터 랩에서 show() 메서드를 통해 그래프를 그려보면 별도의 Window 객체를 생성하지 않고 jupyter widget으로 결과를 보여줍니다.
#
# 반대로 파이썬을 독립 실행하는 경우에는 하나의 Figure당 하나의 Window를 별도로 가집니다.
#
# 이 때 Matplotlib backends는 Figure windows에 대한 확대 및 축소 기능을 지원합니다.

# %% [markdown]
# ### < Figure - Figure 객체 얻기 plt.gcf() >
#
# 현재 사용하고 있는 Figure 객체를 얻으려면(다른 변수에 할당할 수도 있습니다.)
#
# gcf() 메서드를 사용합니다.

# %%
f1 = plt.figure(1)   # figure(1)이라는 객체를 만들어서 f1에 담음
plt.title("현재의 Figure 객체")
plt.plot([1, 2, 3, 4], 'ro:')

f2 = plt.gcf()
print(f1, id(f1)) # f1의 아이디값 조회
print(f2, id(f2))
plt.show()
# Out:
# Figure(640x480) 1471404931872
# Figure(640x480) 1471404931872

# %% [markdown]
# ### < Axes >
#
# Figure 객체 안에 여러 개의 플롯을 그리드(grid) 형태로 보여야하는 경우도 있습니다.
# Figure 안에 있는 각각의 플롯은 Axes라고 불리는 객체에 속합니다.
#
# Figure 안에 Axes를 생성하려면 원래 subplot()을 사용하여 명시적으로 Axes 객체를 얻어야 합니다.
# 그러나 plot()을 바로 사용해도 자동으로 Figure, Axes 객체를 생성해 줍니다.

# %% [markdown]
# ### < Axes >
#
# subplot()은 그리드(grid) 형태의 "Axes 객체들"을 생성합니다.
#
# Figure가 행렬(matrix)이고 Axes가 행렬의 원소라고 생각하면 됩니다.
#
# 예를 들어 위와 아래 두 개의 플롯이 있는 경우 행이 2 이고 열이 1인 2x1 행렬입니다.
#
# subplot 명령은 세개의 인수를 가지는데 처음 두개의 원소가 전체 그리드 행렬의 모양을 지시하는 두 숫자이고 세번째 인수가 네 개 중 어느것인지를 의미하는 숫자가 됩니다.

# %%
ax1 = plt.subplot(2, 1, 1)
# 여기에서 윗부분에 그릴 플룻 명령 실행

ax2 = plt.subplot(2, 1, 2)
# 여기에서 아랫부분에 그릴 플롯 명령 실행

# %% [markdown]
# - 위/아래 두 개의 플롯을 하나의 Figure 안에 그리려면 다음처럼 명령을 실행해야 합니다.
#
# - 여기에서 숫자 인덱싱은 파이썬이 아닌 Matlab 관행을 따르기 때문에 첫번째 플롯을 가리키는 숫자가 0이 아니라 1임에 주의해야 합니다.
#
# - tight_layout() 명령을 실행하면 플롯 간의 간격을 자동으로 맞춰줍니다.

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

ax1 = plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillcation')

ax2 = plt.subplot(2, 1, 2)
plt.plot(x2, y2, 'r.-')
plt.xlabel('times (s)')
plt.ylabel('Undamped')

plt.tight_layout()
plt.show()

# %% [markdown]
# - 만약 2x2 형태의 네 개의 플롯이라면 다음과 같이 그립니다.
#
# - 이 때 subplot 의 인수는 (2,2,1)를 줄여서 221 라는 하나의 숫자로 표시할 수도 습니다.
#
# - Axes의 순서는 콘솔 출력 순서와 동일합니다(좌에서 우로, 위에서 아래로).

# %%
np.random.seed(0)

plt.subplot(221)
plt.plot(np.random.rand(5))
plt.title("axes 1")

plt.subplot(222)
plt.plot(np.random.rand(5))
plt.title("axes 2")

plt.subplot(223)
plt.plot(np.random.rand(5))
plt.title("axes 3")

plt.subplot(224)
plt.plot(np.random.rand(5))
plt.title("axes 4")

plt.tight_layout()
plt.show()

# %% [markdown]
# - subplots()에 인수를 두개만 전달하면 복수의 Axes 객체를 동시에 생성할 수도 있습니다.
#
# - 이때는 2차원 ndarray 형태로 Axes 객체가 반환됩니다.

# %%
fig, axes = plt.subplots(2, 2)

np.random.seed(0)
axes[0, 0].plot(np.random.rand(5))
axes[0, 0].set_title("axes 1")
axes[0, 1].plot(np.random.rand(5))
axes[0, 1].set_title("axes 2")
axes[1, 0].plot(np.random.rand(5))
axes[1, 0].set_title("axes 3")
axes[1, 1].plot(np.random.rand(5))
axes[1, 1].set_title("axes 4")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### < Axes >
#
# Axes는 데이터 플로팅을 위한 영역으로 Figure에 포함되는 Artist입니다.
#
# 일반적으로 2차원의 경우 Axis 객체를 두 개 포함합니다.
# (3차원의 경우 Axis 객체를 세 개 포함)
#
# Axis는 ticks와 tick labels을 제공하며 이는 Axes의 데이터 범위에 대한 척도가 됩니다.
#
# *** - Axes와 Axis는 다른 객체이므로 잘 구분해서 봐야 합니다. ***
#
# Axes 클래스와 그 메서드는 주요한 Entry point이며, 대부분의 플로팅 메서드가 정의되어 있습니다
#
# ![image.png](attachment:1a882bca-14a8-4d38-b8c0-09c9103dd8e0.png)

# %% [markdown]
# ### < Axis : 축 >
#
# 하나의 Axes 객체는 두 개 이상의 Axis 객체를 가집니다.
# Axis 객체는 플롯의 가로축이나 세로축을 나타내는 객체입니다.
#
# Axis 객체는 ticks(축의 표시)과 ticklabels(눈금 레이블을 지정하는 문자열)에 대한 규모와 제한을 설정합니다.
#
# ticks의 위치는 Locator 객체에 의해 결정되며, 눈금 레이블 문자열은 Formatter 객체에 의해 형식이 지정됩니다.
#
# Locator와 Formatter 객체를 올바르게 조합하면 매우 세밀하게 tick 위치와 labels을 제어할 수 있습니다.
#
# ![image.png](attachment:3596cb05-2f71-49c4-9322-e2a69de20cdc.png)

# %% [markdown]
# ### < Axis >
#
# 여러가지 플롯을 하나의 Axes 객체에 표시할 때 y값의 크기가 달라서 표시하기 힘든
# 경우가 있습니다.
#
# 이 때는 다음처럼 twinx 명령으로 대해 복수의 y 축을 가진 플롯을 만들수도 있습니다.
#
# twinx 명령은 x 축을 공유하는 새로운 Axes 객체를 만듭니다.

# %%
fig, ax0 = plt.subplots()
ax1 = ax0.twinx()
ax0.set_title('2개의 y축 한 figure에서 사용하기')
ax0.plot([10, 5, 2, 9, 7], 'r-', label = 'y0')
ax0.set_ylabel('y0')
ax0.grid(False)
ax1.plot([100, 200, 220, 180, 120], 'g:', label = 'y1')
ax1.set_ylabel('y1')
ax1.grid(False)
ax0.set_xlabel('공유되는 x축')
plt.show()

# %% [markdown]
# ### < Artist >
#
# 기본적으로 Figure에 보이는 모든 것들을 Artist라고 합니다.
#
# 이는 Figure, Axes, Axis 객체도 포함됩니다.
#
# 또 Text 객체, Line2D 객체, collections 객체, Patch 객체 등도 포함됩니다.
#
# Figure가 렌더링될 때, 모든 Artists가 그려집니다.
#
# 대부분의 Artists는 하나의 Axes에 묶여 있습니다.
#
# 이러한 Artists는 여러 Axes에 공유되거나 이동할 수 없습니다.

# %% [markdown]
# ### < 바 차트 >
#
# x 데이터가 카테고리 값인 경우에는 bar 명령과 barh 명령으로 바 차트(bar chart)
# 시각화를 할 수 있습니다.
#
# 가로 방향으로 바 차트를 그리려면 barh 명령을 사용합니다.
#
# 바 차트 작성시 주의점은 첫번째 인수인 left 가 x축에서 바(bar)의 왼쪽 변의 위치를 나타낸다는 점입니다.

# %%
x = ['가', '나', '다']
y = [2, 3, 1]
plt.title('Bar chart')
plt.bar(x, y)
plt.xlabel('가나다')
plt.ylabel('빈도수')
plt.show()

# %% [markdown]
# ### < 바 차트 >
#
# 각 bar 마다 색상을 적용할 수 있습니다.
#
# 적용하고 싶은 색상을 데이터 순으로 리스트로 생성합니다.
#
# 생성한 리스트를 bar()의 color 키워드 인수로 전달하면 됩니다.
#
# 그러면 아래와 같은 색상을 갖는 바 차트를 완성할 수 있습니다.

# %%
x = ['가', '나', '다']
y = [2, 3, 1]
colors = ['red', 'pink', 'blue']

plt.title('Bar chart')
plt.bar(x, y, color = colors)
plt.xlabel('가나다')
plt.ylabel('빈도수')
plt.show()

# %% [markdown]
# ### < 바 차트 >
#
# xerr 인수나 yerr 인수를 지정하면 에러 바(error bar)를 추가할 수 있습니다.
#
# 다음 코드에서 alpha는 투명도를 지정한다. 0이면 완전 투명, 1이면 완전 불투명입니다.

# %%
np.random.seed(0)

people = ['몽룡', '춘향', '방자', '향단']
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

plt.title("Barh Chart")
plt.barh(people, performance, xerr = error, alpha = 0.4)
plt.xlabel('x 라벨')
plt.show()

# %% [markdown]
# ### < 연습 문제 >
#
# 타이타닉 데이터셋을 Seaborn 패키지로부터 불러오고, 사망자와 생존자를 Matplotlib의 바 차트로 표현해보세요.

# %%
import seaborn as sns

# %%
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
a = titanic.survived.value_counts()
a
# Out:
# 0    549
# 1    342
# Name: survived, dtype: int64

# %%
x = ['사망자', '생존자']
y = a

bar_colors = ['red', 'green']


plt.title("타이타닉 생존 여부")
plt.barh(x, y, color = bar_colors)
plt.xlabel('인원 수')
plt.show()

# %% [markdown]
# ![image.png](attachment:990ec3ae-5a98-4ccb-920c-b65ada560a8d.png)

# %% [markdown]
# 이거 해설은 모야
#
# ![image.png](attachment:2405aed7-1997-4646-b8eb-b3e302419936.png)

# %% [markdown]
# ### < 파이 차트 >
#
# 카테고리 별 값의 상대적인 비교를 해야 할 때는 pie 명령으로 파이 차트(pie chart)를 그릴 수 있습니다.

# %%
labels = ['월세', '전세', '자가', '기타']
sizes = [15, 30, 45, 10]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
explode = (0, 0, 0.1, 2)
plt.title("Pie Chart")
plt.pie(sizes, explode = explode, labels = labels, colors = colors,
        autopct = '%1.1f%%' ,shadow = True, startangle = 90)
plt.axis('equal') # 원의 형태를 유지
plt.show()

# %% [markdown]
# ### < 연습 문제 >
#
# 타이타닉호 승객을 ‘미성년자’, ‘청년’, ‘장년’, ‘중년’, ‘노년’ 나이 그룹으로 나눕니다.
# 그리고 각 나이 그룹의 승객 비율을 파이 차트로 출력해보세요.
#
# - 단 NaN 값은 배제합니다.
# - 그림자: True
# - 시작 각도: 90
# - autopct: ‘%1.1f%%’

# %% [raw]
# bins = [0, 20, 30, 50, 70, 100]
# labels = ["미성년자", "청년", "장년", "중년", "노년"]
# explode = (0.1, 0, 0, 0, 0)
# colors = ["yellowgreen", "gold", "lightskyblue", "lightcoral", "orange"]

# %%
import pandas as pd

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
bins = [0, 20, 30, 50, 70, 100]
labels = ["미성년자", "청년", "장년", "중년", "노년"]
explode = (0.1, 0, 0, 0, 0)
colors = ["yellowgreen", "gold", "lightskyblue", "lightcoral", "orange"]

a = pd.cut(titanic.age, bins, labels=labels).dropna()
t_age = titanic.value_counts(a, normalize=True)
t_age
# Out:
# age
# 청년      0.456790
# 장년      0.270483
# 미성년자    0.200898
# 중년      0.066218
# 노년      0.005612
# dtype: float64

# %% [raw]
# ##########다들 왜 장년이 젤 많냐 나는 청년인데!!!!!

# %%
plt.pie(t_age, explode = explode, labels = t_age.index, colors = colors,
        autopct = '%1.1f%%', shadow = True, startangle = 90)
plt.axis('equal')
plt.show()

# %% [markdown]
# ### < 히스토그램 >
#
# 히스토그램을 그리기 위한 hist 명령도 있습니다.
#
# hist 명령은 bins 인수로 데이터를 집계할 구간 정보를 받습니다.
#
# 반환값으로 데이터 집계 결과를 반환합니다.

# %%
np.random.seed(0)
x = np.random.randn(1000)
plt.title('Histogram')
arrays, bis, patches = plt.hist(x, bins = 10)
plt.show()

# %%
arrays
# Out:
# array([  9.,  20.,  70., 146., 217., 239., 160.,  86.,  38.,  15.])

# %%
bins
# Out:
# [0, 20, 30, 50, 70, 100]

# %% [markdown]
# ### < 스캐터 플롯 >
#
# 2차원 데이터, 즉 두 개의 실수 데이터 집합의 상관관계를 살펴보려면 scatter 명령으로 스캐터 플롯을 그립니다.
#
# 스캐터 플롯의 점 하나의 위치는 데이터 하나의 x, y 값입니다.

# %%
np.random.seed(0)
X = np.random.normal(0, 1, 100)
Y = np.random.normal(0, 1, 100)
plt.title('Scatter Plot')
plt.scatter(X, Y)
plt.show()

# %% [markdown]
# ### < 스캐터 플롯 >
#
# 데이터가 2차원이 아니라 3차원 혹은 4차원인 경우에는 점 하나의 크기 혹은 색깔을
# 이용하여 다른 데이터 값을 나타낼 수도 있다.
#
# 이런 차트를 버블 차트(bubble chart)라고 한다.
#
# 크기는 s 인수로 색깔은 c 인수로 지정한다.

# %%
N = 30
np.random.seed(0)

x = np.random.rand(N)
y1 = np.random.rand(N)
y2 = np.random.rand(N)
y3 = np.pi * ( 15 *np.random.rand(N))**2

plt.title("Bubble Chart")
plt.scatter(x, y1, c=y2, s=y3)
plt.show()

# %% [markdown]
# ### < imshow >
#
# 화상(image) 데이터처럼 행과 열을 가진 행렬 형태의 2차원 데이터는 imshow 명령을 써서 2차원 자료의 크기를 색깔로 표시하는 것이다.

# %%
from sklearn.datasets import load_digits
digits = load_digits()
X = digits.images[0]
X
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %%
plt.title("mnist digits; 0")
plt.imshow(X, interpolation = 'nearest', cmap = plt.cm.bone_r)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.subplots_adjust(left = 0.35, right = 0.65, bottom = 0.35, top = 0.65)
plt.show()

# %% [markdown]
# ### < imshow >
#
# 데이터 수치를 색으로 바꾸는 함수는 칼라맵(color map)이라고 한다.
#
# 칼라맵은 cmap 인수로 지정한다.
#
# 사용할 수 있는 칼라맵은 plt.cm의 속성으로 포함되어 있다.
#
# 아래에 일부 칼라맵을 표시하였다.

# %%
dir(plt.cm)[:10]
# Out:
# ['Accent',
#  'Accent_r',
#  'Blues',
#  'Blues_r',
#  'BrBG',
#  'BrBG_r',
#  'BuGn',
#  'BuGn_r',
#  'BuPu',
#  'BuPu_r']

# %% [markdown]
# ### < imshow >
#
# 아래 예제는 cmap 키워드 인수를 사용하여 다양한 색상으로 변경된 결과를 출력하고
# 있습니다.

# %%
fig, axes = plt.subplots(1, 4, figsize = (12, 3),
                         subplot_kw = {'xticks' : [], 'yticks' : []})
axes[0].set_title('plt.cm.Blues')
axes[0].imshow(X, interpolation = 'nearest', cmap = plt.cm.Blues)
axes[1].set_title('plt.cm.Blues_r')
axes[1].imshow(X, interpolation = 'nearest', cmap = plt.cm.Blues_r)
axes[2].set_title('plt.BrBG')
axes[2].imshow(X, interpolation = 'nearest', cmap = 'BrBG')
axes[3].set_title('plt.BrBG_r')
axes[3].imshow(X, interpolation = 'nearest', cmap = 'BrBG_r')

plt.show()

# %% [markdown]
# ### < imshow >
# imshow 명령은 자료의 시각화를 돕기위해 다양한 2차원 인터폴레이션을 지원합니다.

# %%
methods = {
    None, 'none', 'nearest', 'bilinear', 'bicubic', 'spline16', 'spline36',
    'hanning', 'hamming', 'hermite', 'kaiser', 'quadric', 'catrom', 'gaussian',
    'bessel', 'mitchell', 'sinc', 'lanczos'
}
fig, axes = plt.subplots(3, 6, figsize = (12, 6),
                         subplot_kw = {'xticks' : [], 'yticks' : []})
for ax, interp_method in zip(axes.flat, methods):
    ax.imshow(X, cmap = plt.cm.bone_r, interpolation = interp_method)
    ax.set_title(interp_method)
plt.show()

# %% [markdown]
# ### < 컨투어 플롯 >
#
# 입력 변수가 x, y 두 개이고 출력 변수가 z 하나인 경우에는 3차원 자료가 된다.
#
# 3차원 자료를 시각화하는 방법은 명암이 아닌 등고선(contour)을 사용하는 방법이다.
#
# contour 혹은 contourf 명령을 사용한다. contour는 등고선만 표시하고 contourf는 색깔로 표시한다.
#
# 입력 변수 x, y는 그대로 사용할 수 없고 meshgrid 명령으로 그리드 포인트 행렬을 만들어야 한다.

# %%
def f(x,y):
    return (1-x / 2 +x ** 5 + y **3) * np.exp(-x ** 2 - y **2)
n=256
x = np.linspace(-3,3,n)
y = np.linspace(-3,3,n)
XX,YY = np.meshgrid(x,y)
ZZ = f(XX, YY)

plt.title('Contour plots')
plt.contourf(XX,YY,ZZ, alpha=.75,cmap='jet')
plt.contour(XX,YY,ZZ, colors='black')
plt.show()

# %% [markdown]
# ### < 3D 서피스 플롯 >
#
# 3차원 플롯은 등고선 플롯과 달리 Axes3D라는 3차원 전용 axes를 생성하여 입체적으로 표시한다.
#
# plot_wireframe(), plot_surface() 명령을 사용한다

# %%
from mpl_toolkits.mplot3d import Axes3D
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
XX, YY = np.meshgrid(X, Y)
RR = np.sqrt(XX**2 + YY**2)
ZZ = np.sin(RR)

fig = plt.figure()
ax = Axes3D(fig)
ax.set_title("3D Surface Plot")
ax.plot_surface(XX, YY, ZZ, rstride = 1, cstride = 1, cmap = 'hot')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6868\4053421420.py:9: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
